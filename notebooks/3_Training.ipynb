# %%
import torch
import matplotlib

# %%
# %run 2._Market-Simulators.ipynb
# Out:
# The Std. Error of the Mean is 0.06726297736167908
# At Epoch No. 10/100, CVaR Loss is -9733319688192.0000
# At Epoch No. 20/100, CVaR Loss is -15417711616.0000
# At Epoch No. 30/100, CVaR Loss is -668682560.0000
# At Epoch No. 40/100, CVaR Loss is -413639936.0000
# At Epoch No. 50/100, CVaR Loss is -2881137920.0000
# At Epoch No. 60/100, CVaR Loss is -3244763136.0000
# At Epoch No. 70/100, CVaR Loss is -7532699136.0000
# At Epoch No. 80/100, CVaR Loss is -97015088.0000
# At Epoch No. 90/100, CVaR Loss is -15289818.0000
# At Epoch No. 100/100, CVaR Loss is -434342784.0000
# At Epoch No. 10/100, Entropic Loss is nan
# At Epoch No. 20/100, Entropic Loss is nan
# At Epoch No. 30/100, Entropic Loss is nan
# At Epoch No. 40/100, Entropic Loss is nan
# At Epoch No. 50/100, Entropic Loss is nan
# At Epoch No. 60/100, Entropic Loss is nan
# At Epoch No. 70/100, Entropic Loss is nan
# At Epoch No. 80/100, Entropic Loss is nan
# At Epoch No. 90/100, Entropic Loss is nan
# ...
