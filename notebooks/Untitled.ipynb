# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.9.1+cu126
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org
# Author:
# Author-email: PyTorch Team <packages@pytorch.org>
# License: BSD-3-Clause
# Location: C:\Users\tonmo\Development\QuantumDeepHedgingProjectsHome\Quantum-Deep-Hedging\env\Lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, setuptools, sympy, typing-extensions
# Required-by: torchaudio, torchvision

# %%
# A few utility functions to help with pytorch operations

'''
returns 'cuda' if appropriate GPU is availabel, else returns 'cpu'
'''
def get_torch_device():
    import torch
    return 'cuda' if torch.cuda.is_available() else 'cpu'
get_torch_device()
# Out:
# 'cuda'
